# %% [markdown]
# <a href="https://colab.research.google.com/github/wuchenyu38/18ma573chenyuwu/blob/master/src/MA_573(HW1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import matplotlib.mlab as mlab

mu = 1
variance = 2
sigma = math.sqrt(variance)
x = np.linspace(mu-3*variance, mu+3*variance, 1000)
plt.title('pdf')
plt.plot(x,mlab.normpdf(x, mu, sigma))
plt.show()

# %% [markdown]
# $$
# pdf=
# \frac{1}{
# \sqrt[1]{8\pi}}
# \times
# e^{
# -\frac{(x-1)^2}{8}
# }
# $$

# %%
import scipy.stats as sc
y = sc.norm.pdf(x, mu, sigma)
yc= sc.norm.cdf(x, mu, sigma)
plt.title('pdf')
plt.plot(x, y,)
plt.show()
